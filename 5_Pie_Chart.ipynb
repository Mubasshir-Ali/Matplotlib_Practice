# %% [markdown]
# # Pie Chart

# %%
import matplotlib.pyplot as plt

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# draw pie chart
plt.pie(1)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# draw pie chart
plt.pie(class1_students)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# draw pie chart
# show labels
plt.pie(class1_students, labels = classes)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0, 0, 0, 0]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0.1, 0, 0, 0, 0]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0, 0.1, 0, 0]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0, 0, 0.1, 0]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0, 0, 0, 0.1]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0.1, 0, 0.2, 0, 0]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
plt.pie(class1_students, labels = classes, explode = explode)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]

plt.pie(class1_students, labels = classes, explode = explode, colors = colors)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# using percentage autopct
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%")
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# using percentage autopct
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.2f%%")
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# using shadow
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# using shadow
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# using start angle
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# using start angle
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 270)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# using text properties
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# using pctdistance
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# using labeldistance
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.1)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# using counterclock
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.1, counterclock = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 1, "edgecolor" : "k"}
# using counterclock
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.1, counterclock = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 1, "edgecolor" : "k"}
# using center
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3))
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 1, "edgecolor" : "k"}
# using frame
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 1, "edgecolor" : "k"}
# using rotate labels
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True, rotatelabels = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use wedgeprops
wedprops = {"linewidth" : 4, 'width' : 2, "edgecolor" : "k"}
# using rotate labels
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True, rotatelabels = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 3, "edgecolor" : "k"}
# using rotate labels
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True, rotatelabels = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use plot figure
plt.figure(figsize = (6, 1))
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 3, "edgecolor" : "k"}
# using rotate labels
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True, rotatelabels = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use plot figure
plt.figure(figsize = (6, 4))
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 3, "edgecolor" : "k"}
# using rotate labels
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True, rotatelabels = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use plot figure
plt.figure(figsize = (6, 2))
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 3, "edgecolor" : "k"}
# using rotate labels
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True, rotatelabels = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# use plot figure
plt.figure(figsize = (6, 1))
# use wedgeprops
wedprops = {"linewidth" : 4, "width" : 3, "edgecolor" : "k"}
# using rotate labels
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.5, startangle = 90, pctdistance = 0.5, labeldistance = 1.4, counterclock = True, center = (2, 3), frame = True, rotatelabels = True)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# using text props
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 270, textprops = textprops)
plt.show()

# %%
classes = ["Python", "R", "Machine Learning", "Artificial Intelligence", "Data Science"]

class1_students = [45, 15, 35, 25, 30]

# explode mean slicing
explode = [0, 0.1, 0, 0, 0.1]
# using color
colors = ["c", "b", "r", "y", "g"]
# use text properties
textprops = {"fontsize" : 14}
# using text props
plt.pie(class1_students, labels = classes, explode = explode, colors = colors, autopct = "%0.1f%%", shadow = True, radius = 1.4, startangle = 270, textprops = textprops)
# use legend
plt.legend()
plt.show()

# %%
import numpy as np

plt.figure(figsize = (8, 5))

colors = ['r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w']
labels = np.ones(20)

plt.pie([1], colors = "k", radius = 2.05)
plt.pie(labels, colors = colors, radius = 2.0)

plt.pie([1], colors = "g", radius = 1.8)
plt.pie([1], colors = "y", radius = 1.6)
plt.pie([1], colors = "c", radius = 1.3)
plt.pie([1], colors = "b", radius = 1.1)
plt.pie([1], colors = "m", radius = 0.9)

plt.pie([1], colors = "b", radius = 0.31)
plt.pie(labels, colors = colors, radius = 0.3)

plt.pie([1], colors = "w", radius = 0.2)
plt.pie([1], colors = "k", radius = 0.1)

plt.show()

# %%
import numpy as np

plt.figure(figsize = (7, 4))

colors = ['r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w', 'r', 'w']
labels = np.ones(20)

plt.pie([1], colors = "k", radius = 2.05)
plt.pie(labels, colors = colors, radius = 2.0)

plt.pie([1], colors = "g", radius = 1.8)
plt.pie([1], colors = "y", radius = 1.6)
plt.pie([1], colors = "c", radius = 1.3)
plt.pie([1], colors = "b", radius = 1.1)
plt.pie([1], colors = "m", radius = 0.9)

plt.pie([1], colors = "b", radius = 0.31)
plt.pie(labels, colors = colors, radius = 0.3)

plt.pie([1], colors = "w", radius = 0.2)
plt.pie([1], colors = "k", radius = 0.1)

plt.show()
